# %%
# !pip install "gluonts[torch]"
# Out:
# Requirement already satisfied: gluonts[torch] in /opt/conda/lib/python3.10/site-packages (0.14.4)
# Requirement already satisfied: numpy~=1.16 in /opt/conda/lib/python3.10/site-packages (from gluonts[torch]) (1.26.4)
# Requirement already satisfied: pandas<2.2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from gluonts[torch]) (2.1.4)
# Requirement already satisfied: pydantic<3,>=1.7 in /opt/conda/lib/python3.10/site-packages (from gluonts[torch]) (2.5.3)
# Requirement already satisfied: tqdm~=4.23 in /opt/conda/lib/python3.10/site-packages (from gluonts[torch]) (4.66.1)
# Requirement already satisfied: toolz~=0.10 in /opt/conda/lib/python3.10/site-packages (from gluonts[torch]) (0.12.1)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/conda/lib/python3.10/site-packages (from gluonts[torch]) (4.9.0)
# Requirement already satisfied: torch<3,>=1.9 in /opt/conda/lib/python3.10/site-packages (from gluonts[torch]) (2.1.2)
# Requirement already satisfied: lightning<2.2,>=2.0 in /opt/conda/lib/python3.10/site-packages (from gluonts[torch]) (2.1.4)
# Requirement already satisfied: pytorch-lightning<2.2,>=2.0 in /opt/conda/lib/python3.10/site-packages (from gluonts[torch]) (2.1.4)
# Requirement already satisfied: scipy~=1.10 in /opt/conda/lib/python3.10/site-packages (from gluonts[torch]) (1.11.4)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /opt/conda/lib/python3.10/site-packages (from lightning<2.2,>=2.0->gluonts[torch]) (6.0.1)
# Requirement already satisfied: fsspec<2025.0,>=2022.5.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->gluonts[torch]) (2024.2.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from lightning<2.2,>=2.0->gluonts[torch]) (0.11.2)
# Requirement already satisfied: packaging<25.0,>=20.0 in /opt/conda/lib/python3.10/site-packages (from lightning<2.2,>=2.0->gluonts[torch]) (21.3)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from lightning<2.2,>=2.0->gluonts[torch]) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas<2.2.0,>=1.0->gluonts[torch]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.2.0,>=1.0->gluonts[torch]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.2.0,>=1.0->gluonts[torch]) (2023.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.7->gluonts[torch]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1.7->gluonts[torch]) (2.14.6)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch<3,>=1.9->gluonts[torch]) (3.13.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch<3,>=1.9->gluonts[torch]) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch<3,>=1.9->gluonts[torch]) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch<3,>=1.9->gluonts[torch]) (3.1.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->gluonts[torch]) (3.9.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities<2.0,>=0.8.0->lightning<2.2,>=2.0->gluonts[torch]) (69.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging<25.0,>=20.0->lightning<2.2,>=2.0->gluonts[torch]) (3.1.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<2.2.0,>=1.0->gluonts[torch]) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch<3,>=1.9->gluonts[torch]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch<3,>=1.9->gluonts[torch]) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->gluonts[torch]) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->gluonts[torch]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->gluonts[torch]) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->gluonts[torch]) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->gluonts[torch]) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->gluonts[torch]) (4.0.3)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning<2.2,>=2.0->gluonts[torch]) (3.6)

# %%
import pandas as pd
import numpy as np
from gluonts.dataset.pandas import PandasDataset
from gluonts.torch.model.deepar import DeepAREstimator
#from gluonts.torch.distributions import NegativeBinomialOutput
from gluonts.torch.distributions import NormalOutput
import json

# %%
def Create_Data_Window(df,N,W,stride):
    '''
    Create W windows
    '''
    lis = []
    for i in range(W):
        lis.append(df.iloc[:(N+i*stride)*111,:].reset_index().iloc[:,1:])
    return lis

# %%
def Create_testData_Window(df,N,W,stride):
    '''
    Create W windows
    '''
    lis = []
    for i in range(W):
        lis.append(df.iloc[(N+i*stride)*111:(N+(i+1)*stride)*111,:].reset_index().iloc[:,1:])
    return lis

# %%
# Split train and test
path = '/kaggle/input/tourism-data/'
df = pd.read_csv(path+'Tourism_process_for_deepar.csv')
#df.set_index('Date',inplace=True)
prediction_length = 12
freq = 'MS'
N = 168
stride = 12
W = 4

train_lis = Create_Data_Window(df,N,W,stride)


train1 = train_lis[0].drop_duplicates(subset=['Node','Region','Zone','State'])
train_static = pd.DataFrame({'State':train1['State'],
                             'Zone':train1['Zone'],
                             'Region':train1['Region'],
                             'Node':train1['Node']})
train_static.set_index('Node',inplace=True)

sp = []
train_standard_lis = []
for train_ds in train_lis:
    train_group = train_ds.groupby('Node')
    standardized_params = {}
    train_standard = train_ds.copy()
    for cat,group in train_group:
        means = group['Value'].mean()
        stds = group['Value'].std()
        standardized_params[cat] = {'mean':means,'std':stds}
        train_standard.loc[group.index,'Value'] = (group['Value']-means)/stds
        
    train_standard_ds = PandasDataset.from_long_dataframe(train_standard.iloc[:,[0,1,2,3]],
                                                target="Value",
                                                timestamp='Date',
                                                freq='M',
                                                item_id="Node",
                                                feat_dynamic_real=["Month_Of_Year"],
                                                static_features=train_static)
    
    train_standard_lis.append(train_standard_ds)
    sp.append(standardized_params)

# %%
test_lis = Create_testData_Window(df,N,W,stride)

# %%
test_ds_lis = []
for i in range(len(test_lis)):
    test_ds = PandasDataset.from_long_dataframe(test_lis[i].iloc[:,[0,1,2,3]],
                                                 target="Value",
                                                 item_id="Node",
                                                 feat_dynamic_real=["Month_Of_Year"],
                                                 static_features=train_static,
                                                 timestamp='Date',
                                                 freq='M')
    test_ds_lis.append(test_ds)

# %%
from gluonts.evaluation import make_evaluation_predictions
for i in range(3,4):
    # Estimator
    estimator = DeepAREstimator(freq=freq,
                                prediction_length=prediction_length,
                                context_length=10*prediction_length,
                                num_layers=3,
                                hidden_size=41,
                                lr=1e-2,
                                weight_decay=1e-8,
                                dropout_rate=0.1,
                                num_feat_dynamic_real=1,
                                num_feat_static_real=3,
                                distr_output=NormalOutput(),
                                patience=10,
                                scaling=False,
                                num_parallel_samples=1000,
                                batch_size=16,
                                trainer_kwargs={'accelerator':'gpu','max_epochs':300})

    # Train
    predictor = estimator.train(train_standard_lis[i],cache_data=True)

    # Predict
    # forecast_it = predictor.predict(test_ds_lis[i],num_samples=1000)
    # forecasts = list(forecast_it)
    forecast_it, ts_it = make_evaluation_predictions(dataset=test_ds_lis[i], predictor=predictor,num_samples=1000)
    forecasts = list(forecast_it)
    
    # Anti standardized
    f_cp = forecasts
    for index in range(len(forecasts)):
        index_mean = sp[i][forecasts[index].item_id]['mean']
        index_std = sp[i][forecasts[index].item_id]['std']
        f_cp[index].samples = (forecasts[index].samples)*index_std+index_mean

    if i==0:
        # sort
        node_nonsort = []
        new_df = pd.read_csv(path+'/Tourism_process.csv')
        node_list = new_df.columns[2:]
        for k in range(len(forecasts)):
            node_nonsort.append(forecasts[k].item_id)
        index_list = [node_nonsort.index(m) for m in node_list]

    # Save the distri params
    distr_params = []
    for j in range(12):
        params_mean = []
        params_var = []
        for m in range(len(forecasts)):
            params_mean.append(float(np.mean(forecasts[m].samples[:,j])))
            params_var.append(float(np.var(forecasts[m].samples[:,j],ddof=1)))
        distr_params.append([params_mean,params_var])

    distr_params_new = distr_params
    for j in range(12):
        distr_params_new[j][0] = [distr_params[j][0][k] for k in index_list]
        distr_params_new[j][1] = [distr_params[j][1][k] for k in index_list]

    with open('Tourism_deepar_e300_optuna_in_{}.json'.format(i+1),'w') as file:
        file.write(json.dumps(distr_params_new))
# Out:
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: IPU available: False, using: 0 IPUs
# INFO: HPU available: False, using: 0 HPUs
# /opt/conda/lib/python3.10/site-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name  | Type        | Params | In sizes                                                      | Out sizes
# ----------------------------------------------------------------------------------------------------------------------
# 0 | model | DeepARModel | 38.6 K | [[1, 1], [1, 3], [1, 156, 3], [1, 156], [1, 156], [1, 12, 3]] | [1, 1000, 12]
# ----------------------------------------------------------------------------------------------------------------------
# 38.6 K    Trainable params
# 0         Non-trainable params
# 38.6 K    Total params
# 0.154     Total estimated model params size (MB)
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO: Epoch 0, global step 50: 'train_loss' reached 0.95634 (best 0.95634), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO: Epoch 1, global step 100: 'train_loss' reached 0.80588 (best 0.80588), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO: Epoch 2, global step 150: 'train_loss' reached 0.79586 (best 0.79586), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO: Epoch 3, global step 200: 'train_loss' was not in top 1
# INFO: Epoch 4, global step 250: 'train_loss' reached 0.75610 (best 0.75610), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=4-step=250.ckpt' as top 1
# INFO: Epoch 5, global step 300: 'train_loss' was not in top 1
# INFO: Epoch 6, global step 350: 'train_loss' reached 0.74473 (best 0.74473), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=6-step=350.ckpt' as top 1
# INFO: Epoch 7, global step 400: 'train_loss' reached 0.71578 (best 0.71578), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=7-step=400.ckpt' as top 1
# INFO: Epoch 8, global step 450: 'train_loss' reached 0.69503 (best 0.69503), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=8-step=450.ckpt' as top 1
# INFO: Epoch 9, global step 500: 'train_loss' reached 0.65500 (best 0.65500), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=9-step=500.ckpt' as top 1
# INFO: Epoch 10, global step 550: 'train_loss' was not in top 1
# INFO: Epoch 11, global step 600: 'train_loss' was not in top 1
# INFO: Epoch 12, global step 650: 'train_loss' reached 0.65229 (best 0.65229), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=12-step=650.ckpt' as top 1
# INFO: Epoch 13, global step 700: 'train_loss' was not in top 1
# INFO: Epoch 14, global step 750: 'train_loss' reached 0.63270 (best 0.63270), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=14-step=750.ckpt' as top 1
# INFO: Epoch 15, global step 800: 'train_loss' was not in top 1
# INFO: Epoch 16, global step 850: 'train_loss' reached 0.62658 (best 0.62658), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=16-step=850.ckpt' as top 1
# INFO: Epoch 17, global step 900: 'train_loss' was not in top 1
# INFO: Epoch 18, global step 950: 'train_loss' reached 0.60058 (best 0.60058), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=18-step=950.ckpt' as top 1
# INFO: Epoch 19, global step 1000: 'train_loss' reached 0.55000 (best 0.55000), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=19-step=1000.ckpt' as top 1
# INFO: Epoch 20, global step 1050: 'train_loss' was not in top 1
# INFO: Epoch 21, global step 1100: 'train_loss' reached 0.54301 (best 0.54301), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=21-step=1100.ckpt' as top 1
# INFO: Epoch 22, global step 1150: 'train_loss' was not in top 1
# INFO: Epoch 23, global step 1200: 'train_loss' was not in top 1
# INFO: Epoch 24, global step 1250: 'train_loss' was not in top 1
# INFO: Epoch 25, global step 1300: 'train_loss' was not in top 1
# INFO: Epoch 26, global step 1350: 'train_loss' reached 0.53510 (best 0.53510), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=26-step=1350.ckpt' as top 1
# INFO: Epoch 27, global step 1400: 'train_loss' reached 0.51505 (best 0.51505), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=27-step=1400.ckpt' as top 1
# INFO: Epoch 28, global step 1450: 'train_loss' reached 0.51120 (best 0.51120), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=28-step=1450.ckpt' as top 1
# INFO: Epoch 29, global step 1500: 'train_loss' was not in top 1
# INFO: Epoch 30, global step 1550: 'train_loss' reached 0.50471 (best 0.50471), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=30-step=1550.ckpt' as top 1
# INFO: Epoch 31, global step 1600: 'train_loss' was not in top 1
# INFO: Epoch 32, global step 1650: 'train_loss' reached 0.49428 (best 0.49428), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=32-step=1650.ckpt' as top 1
# INFO: Epoch 33, global step 1700: 'train_loss' reached 0.48039 (best 0.48039), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=33-step=1700.ckpt' as top 1
# INFO: Epoch 34, global step 1750: 'train_loss' was not in top 1
# INFO: Epoch 35, global step 1800: 'train_loss' reached 0.47162 (best 0.47162), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=35-step=1800.ckpt' as top 1
# INFO: Epoch 36, global step 1850: 'train_loss' reached 0.46832 (best 0.46832), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=36-step=1850.ckpt' as top 1
# INFO: Epoch 37, global step 1900: 'train_loss' was not in top 1
# INFO: Epoch 38, global step 1950: 'train_loss' reached 0.45990 (best 0.45990), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=38-step=1950.ckpt' as top 1
# INFO: Epoch 39, global step 2000: 'train_loss' reached 0.44200 (best 0.44200), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=39-step=2000.ckpt' as top 1
# INFO: Epoch 40, global step 2050: 'train_loss' was not in top 1
# INFO: Epoch 41, global step 2100: 'train_loss' was not in top 1
# INFO: Epoch 42, global step 2150: 'train_loss' reached 0.43655 (best 0.43655), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=42-step=2150.ckpt' as top 1
# INFO: Epoch 43, global step 2200: 'train_loss' reached 0.43233 (best 0.43233), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=43-step=2200.ckpt' as top 1
# INFO: Epoch 44, global step 2250: 'train_loss' was not in top 1
# INFO: Epoch 45, global step 2300: 'train_loss' reached 0.42394 (best 0.42394), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=45-step=2300.ckpt' as top 1
# INFO: Epoch 46, global step 2350: 'train_loss' was not in top 1
# INFO: Epoch 47, global step 2400: 'train_loss' reached 0.41997 (best 0.41997), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=47-step=2400.ckpt' as top 1
# INFO: Epoch 48, global step 2450: 'train_loss' reached 0.40135 (best 0.40135), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=48-step=2450.ckpt' as top 1
# INFO: Epoch 49, global step 2500: 'train_loss' reached 0.38694 (best 0.38694), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=49-step=2500.ckpt' as top 1
# INFO: Epoch 50, global step 2550: 'train_loss' was not in top 1
# INFO: Epoch 51, global step 2600: 'train_loss' was not in top 1
# INFO: Epoch 52, global step 2650: 'train_loss' was not in top 1
# INFO: Epoch 53, global step 2700: 'train_loss' was not in top 1
# INFO: Epoch 54, global step 2750: 'train_loss' was not in top 1
# INFO: Epoch 55, global step 2800: 'train_loss' was not in top 1
# INFO: Epoch 56, global step 2850: 'train_loss' was not in top 1
# INFO: Epoch 57, global step 2900: 'train_loss' was not in top 1
# INFO: Epoch 58, global step 2950: 'train_loss' was not in top 1
# INFO: Epoch 59, global step 3000: 'train_loss' was not in top 1
# INFO: Epoch 60, global step 3050: 'train_loss' was not in top 1
# INFO: Epoch 61, global step 3100: 'train_loss' was not in top 1
# INFO: Epoch 62, global step 3150: 'train_loss' was not in top 1
# INFO: Epoch 63, global step 3200: 'train_loss' reached 0.36015 (best 0.36015), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=63-step=3200.ckpt' as top 1
# INFO: Epoch 64, global step 3250: 'train_loss' was not in top 1
# INFO: Epoch 65, global step 3300: 'train_loss' was not in top 1
# INFO: Epoch 66, global step 3350: 'train_loss' was not in top 1
# INFO: Epoch 67, global step 3400: 'train_loss' was not in top 1
# INFO: Epoch 68, global step 3450: 'train_loss' was not in top 1
# INFO: Epoch 69, global step 3500: 'train_loss' reached 0.34654 (best 0.34654), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=69-step=3500.ckpt' as top 1
# INFO: Epoch 70, global step 3550: 'train_loss' was not in top 1
# INFO: Epoch 71, global step 3600: 'train_loss' was not in top 1
# INFO: Epoch 72, global step 3650: 'train_loss' was not in top 1
# INFO: Epoch 73, global step 3700: 'train_loss' reached 0.33743 (best 0.33743), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=73-step=3700.ckpt' as top 1
# INFO: Epoch 74, global step 3750: 'train_loss' was not in top 1
# INFO: Epoch 75, global step 3800: 'train_loss' was not in top 1
# INFO: Epoch 76, global step 3850: 'train_loss' was not in top 1
# INFO: Epoch 77, global step 3900: 'train_loss' reached 0.33227 (best 0.33227), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=77-step=3900.ckpt' as top 1
# INFO: Epoch 78, global step 3950: 'train_loss' was not in top 1
# INFO: Epoch 79, global step 4000: 'train_loss' reached 0.31835 (best 0.31835), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=79-step=4000.ckpt' as top 1
# INFO: Epoch 80, global step 4050: 'train_loss' was not in top 1
# INFO: Epoch 81, global step 4100: 'train_loss' was not in top 1
# INFO: Epoch 82, global step 4150: 'train_loss' was not in top 1
# INFO: Epoch 83, global step 4200: 'train_loss' was not in top 1
# INFO: Epoch 84, global step 4250: 'train_loss' was not in top 1
# INFO: Epoch 85, global step 4300: 'train_loss' was not in top 1
# INFO: Epoch 86, global step 4350: 'train_loss' reached 0.31780 (best 0.31780), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=86-step=4350.ckpt' as top 1
# INFO: Epoch 87, global step 4400: 'train_loss' was not in top 1
# INFO: Epoch 88, global step 4450: 'train_loss' reached 0.31440 (best 0.31440), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=88-step=4450.ckpt' as top 1
# INFO: Epoch 89, global step 4500: 'train_loss' was not in top 1
# INFO: Epoch 90, global step 4550: 'train_loss' was not in top 1
# INFO: Epoch 91, global step 4600: 'train_loss' reached 0.30759 (best 0.30759), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=91-step=4600.ckpt' as top 1
# INFO: Epoch 92, global step 4650: 'train_loss' was not in top 1
# INFO: Epoch 93, global step 4700: 'train_loss' was not in top 1
# INFO: Epoch 94, global step 4750: 'train_loss' reached 0.29497 (best 0.29497), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=94-step=4750.ckpt' as top 1
# INFO: Epoch 95, global step 4800: 'train_loss' was not in top 1
# INFO: Epoch 96, global step 4850: 'train_loss' was not in top 1
# INFO: Epoch 97, global step 4900: 'train_loss' was not in top 1
# INFO: Epoch 98, global step 4950: 'train_loss' was not in top 1
# INFO: Epoch 99, global step 5000: 'train_loss' was not in top 1
# INFO: Epoch 100, global step 5050: 'train_loss' was not in top 1
# INFO: Epoch 101, global step 5100: 'train_loss' reached 0.27325 (best 0.27325), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=101-step=5100.ckpt' as top 1
# INFO: Epoch 102, global step 5150: 'train_loss' was not in top 1
# INFO: Epoch 103, global step 5200: 'train_loss' was not in top 1
# INFO: Epoch 104, global step 5250: 'train_loss' was not in top 1
# INFO: Epoch 105, global step 5300: 'train_loss' was not in top 1
# INFO: Epoch 106, global step 5350: 'train_loss' was not in top 1
# INFO: Epoch 107, global step 5400: 'train_loss' was not in top 1
# INFO: Epoch 108, global step 5450: 'train_loss' reached 0.26988 (best 0.26988), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=108-step=5450.ckpt' as top 1
# INFO: Epoch 109, global step 5500: 'train_loss' reached 0.26178 (best 0.26178), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=109-step=5500.ckpt' as top 1
# INFO: Epoch 110, global step 5550: 'train_loss' was not in top 1
# INFO: Epoch 111, global step 5600: 'train_loss' was not in top 1
# INFO: Epoch 112, global step 5650: 'train_loss' was not in top 1
# INFO: Epoch 113, global step 5700: 'train_loss' was not in top 1
# INFO: Epoch 114, global step 5750: 'train_loss' reached 0.22320 (best 0.22320), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=114-step=5750.ckpt' as top 1
# INFO: Epoch 115, global step 5800: 'train_loss' was not in top 1
# INFO: Epoch 116, global step 5850: 'train_loss' was not in top 1
# INFO: Epoch 117, global step 5900: 'train_loss' was not in top 1
# INFO: Epoch 118, global step 5950: 'train_loss' was not in top 1
# INFO: Epoch 119, global step 6000: 'train_loss' was not in top 1
# INFO: Epoch 120, global step 6050: 'train_loss' was not in top 1
# INFO: Epoch 121, global step 6100: 'train_loss' was not in top 1
# INFO: Epoch 122, global step 6150: 'train_loss' was not in top 1
# INFO: Epoch 123, global step 6200: 'train_loss' was not in top 1
# INFO: Epoch 124, global step 6250: 'train_loss' was not in top 1
# INFO: Epoch 125, global step 6300: 'train_loss' was not in top 1
# INFO: Epoch 126, global step 6350: 'train_loss' was not in top 1
# INFO: Epoch 127, global step 6400: 'train_loss' was not in top 1
# INFO: Epoch 128, global step 6450: 'train_loss' was not in top 1
# INFO: Epoch 129, global step 6500: 'train_loss' was not in top 1
# INFO: Epoch 130, global step 6550: 'train_loss' was not in top 1
# INFO: Epoch 131, global step 6600: 'train_loss' was not in top 1
# INFO: Epoch 132, global step 6650: 'train_loss' was not in top 1
# INFO: Epoch 133, global step 6700: 'train_loss' was not in top 1
# INFO: Epoch 134, global step 6750: 'train_loss' was not in top 1
# INFO: Epoch 135, global step 6800: 'train_loss' was not in top 1
# INFO: Epoch 136, global step 6850: 'train_loss' was not in top 1
# INFO: Epoch 137, global step 6900: 'train_loss' was not in top 1
# INFO: Epoch 138, global step 6950: 'train_loss' reached 0.21280 (best 0.21280), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=138-step=6950.ckpt' as top 1
# INFO: Epoch 139, global step 7000: 'train_loss' was not in top 1
# INFO: Epoch 140, global step 7050: 'train_loss' was not in top 1
# INFO: Epoch 141, global step 7100: 'train_loss' was not in top 1
# INFO: Epoch 142, global step 7150: 'train_loss' was not in top 1
# INFO: Epoch 143, global step 7200: 'train_loss' was not in top 1
# INFO: Epoch 144, global step 7250: 'train_loss' was not in top 1
# INFO: Epoch 145, global step 7300: 'train_loss' reached 0.20880 (best 0.20880), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=145-step=7300.ckpt' as top 1
# INFO: Epoch 146, global step 7350: 'train_loss' was not in top 1
# INFO: Epoch 147, global step 7400: 'train_loss' was not in top 1
# INFO: Epoch 148, global step 7450: 'train_loss' was not in top 1
# INFO: Epoch 149, global step 7500: 'train_loss' was not in top 1
# INFO: Epoch 150, global step 7550: 'train_loss' was not in top 1
# INFO: Epoch 151, global step 7600: 'train_loss' was not in top 1
# INFO: Epoch 152, global step 7650: 'train_loss' was not in top 1
# INFO: Epoch 153, global step 7700: 'train_loss' was not in top 1
# INFO: Epoch 154, global step 7750: 'train_loss' was not in top 1
# INFO: Epoch 155, global step 7800: 'train_loss' was not in top 1
# INFO: Epoch 156, global step 7850: 'train_loss' reached 0.19520 (best 0.19520), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=156-step=7850.ckpt' as top 1
# INFO: Epoch 157, global step 7900: 'train_loss' was not in top 1
# INFO: Epoch 158, global step 7950: 'train_loss' was not in top 1
# INFO: Epoch 159, global step 8000: 'train_loss' was not in top 1
# INFO: Epoch 160, global step 8050: 'train_loss' was not in top 1
# INFO: Epoch 161, global step 8100: 'train_loss' was not in top 1
# INFO: Epoch 162, global step 8150: 'train_loss' was not in top 1
# INFO: Epoch 163, global step 8200: 'train_loss' reached 0.19168 (best 0.19168), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=163-step=8200.ckpt' as top 1
# INFO: Epoch 164, global step 8250: 'train_loss' was not in top 1
# INFO: Epoch 165, global step 8300: 'train_loss' was not in top 1
# INFO: Epoch 166, global step 8350: 'train_loss' was not in top 1
# INFO: Epoch 167, global step 8400: 'train_loss' was not in top 1
# INFO: Epoch 168, global step 8450: 'train_loss' was not in top 1
# INFO: Epoch 169, global step 8500: 'train_loss' was not in top 1
# INFO: Epoch 170, global step 8550: 'train_loss' was not in top 1
# INFO: Epoch 171, global step 8600: 'train_loss' was not in top 1
# INFO: Epoch 172, global step 8650: 'train_loss' was not in top 1
# INFO: Epoch 173, global step 8700: 'train_loss' was not in top 1
# INFO: Epoch 174, global step 8750: 'train_loss' was not in top 1
# INFO: Epoch 175, global step 8800: 'train_loss' was not in top 1
# INFO: Epoch 176, global step 8850: 'train_loss' was not in top 1
# INFO: Epoch 177, global step 8900: 'train_loss' was not in top 1
# INFO: Epoch 178, global step 8950: 'train_loss' reached 0.18407 (best 0.18407), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=178-step=8950.ckpt' as top 1
# INFO: Epoch 179, global step 9000: 'train_loss' was not in top 1
# INFO: Epoch 180, global step 9050: 'train_loss' was not in top 1
# INFO: Epoch 181, global step 9100: 'train_loss' was not in top 1
# INFO: Epoch 182, global step 9150: 'train_loss' reached 0.17479 (best 0.17479), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=182-step=9150.ckpt' as top 1
# INFO: Epoch 183, global step 9200: 'train_loss' was not in top 1
# INFO: Epoch 184, global step 9250: 'train_loss' was not in top 1
# INFO: Epoch 185, global step 9300: 'train_loss' was not in top 1
# INFO: Epoch 186, global step 9350: 'train_loss' was not in top 1
# INFO: Epoch 187, global step 9400: 'train_loss' was not in top 1
# INFO: Epoch 188, global step 9450: 'train_loss' was not in top 1
# INFO: Epoch 189, global step 9500: 'train_loss' was not in top 1
# INFO: Epoch 190, global step 9550: 'train_loss' was not in top 1
# INFO: Epoch 191, global step 9600: 'train_loss' was not in top 1
# INFO: Epoch 192, global step 9650: 'train_loss' was not in top 1
# INFO: Epoch 193, global step 9700: 'train_loss' was not in top 1
# INFO: Epoch 194, global step 9750: 'train_loss' was not in top 1
# INFO: Epoch 195, global step 9800: 'train_loss' was not in top 1
# INFO: Epoch 196, global step 9850: 'train_loss' was not in top 1
# INFO: Epoch 197, global step 9900: 'train_loss' was not in top 1
# INFO: Epoch 198, global step 9950: 'train_loss' was not in top 1
# INFO: Epoch 199, global step 10000: 'train_loss' was not in top 1
# INFO: Epoch 200, global step 10050: 'train_loss' was not in top 1
# INFO: Epoch 201, global step 10100: 'train_loss' was not in top 1
# INFO: Epoch 202, global step 10150: 'train_loss' was not in top 1
# INFO: Epoch 203, global step 10200: 'train_loss' reached 0.17429 (best 0.17429), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=203-step=10200.ckpt' as top 1
# INFO: Epoch 204, global step 10250: 'train_loss' was not in top 1
# INFO: Epoch 205, global step 10300: 'train_loss' was not in top 1
# INFO: Epoch 206, global step 10350: 'train_loss' reached 0.17133 (best 0.17133), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=206-step=10350.ckpt' as top 1
# INFO: Epoch 207, global step 10400: 'train_loss' was not in top 1
# INFO: Epoch 208, global step 10450: 'train_loss' was not in top 1
# INFO: Epoch 209, global step 10500: 'train_loss' was not in top 1
# INFO: Epoch 210, global step 10550: 'train_loss' was not in top 1
# INFO: Epoch 211, global step 10600: 'train_loss' was not in top 1
# INFO: Epoch 212, global step 10650: 'train_loss' was not in top 1
# INFO: Epoch 213, global step 10700: 'train_loss' was not in top 1
# INFO: Epoch 214, global step 10750: 'train_loss' was not in top 1
# INFO: Epoch 215, global step 10800: 'train_loss' was not in top 1
# INFO: Epoch 216, global step 10850: 'train_loss' was not in top 1
# INFO: Epoch 217, global step 10900: 'train_loss' was not in top 1
# INFO: Epoch 218, global step 10950: 'train_loss' was not in top 1
# INFO: Epoch 219, global step 11000: 'train_loss' was not in top 1
# INFO: Epoch 220, global step 11050: 'train_loss' was not in top 1
# INFO: Epoch 221, global step 11100: 'train_loss' was not in top 1
# INFO: Epoch 222, global step 11150: 'train_loss' was not in top 1
# INFO: Epoch 223, global step 11200: 'train_loss' was not in top 1
# INFO: Epoch 224, global step 11250: 'train_loss' was not in top 1
# INFO: Epoch 225, global step 11300: 'train_loss' was not in top 1
# INFO: Epoch 226, global step 11350: 'train_loss' was not in top 1
# INFO: Epoch 227, global step 11400: 'train_loss' was not in top 1
# INFO: Epoch 228, global step 11450: 'train_loss' was not in top 1
# INFO: Epoch 229, global step 11500: 'train_loss' was not in top 1
# INFO: Epoch 230, global step 11550: 'train_loss' was not in top 1
# INFO: Epoch 231, global step 11600: 'train_loss' was not in top 1
# INFO: Epoch 232, global step 11650: 'train_loss' was not in top 1
# INFO: Epoch 233, global step 11700: 'train_loss' was not in top 1
# INFO: Epoch 234, global step 11750: 'train_loss' reached 0.16275 (best 0.16275), saving model to '/kaggle/working/lightning_logs/version_34/checkpoints/epoch=234-step=11750.ckpt' as top 1
# INFO: Epoch 235, global step 11800: 'train_loss' was not in top 1
# INFO: Epoch 236, global step 11850: 'train_loss' was not in top 1
# INFO: Epoch 237, global step 11900: 'train_loss' was not in top 1
# INFO: Epoch 238, global step 11950: 'train_loss' was not in top 1
# INFO: Epoch 239, global step 12000: 'train_loss' was not in top 1
# INFO: Epoch 240, global step 12050: 'train_loss' was not in top 1
# INFO: Epoch 241, global step 12100: 'train_loss' was not in top 1
# INFO: Epoch 242, global step 12150: 'train_loss' was not in top 1
# INFO: Epoch 243, global step 12200: 'train_loss' was not in top 1
# INFO: Epoch 244, global step 12250: 'train_loss' was not in top 1
# INFO: Epoch 245, global step 12300: 'train_loss' was not in top 1
# INFO: Epoch 246, global step 12350: 'train_loss' was not in top 1
# INFO: Epoch 247, global step 12400: 'train_loss' was not in top 1
# INFO: Epoch 248, global step 12450: 'train_loss' was not in top 1
# INFO: Epoch 249, global step 12500: 'train_loss' was not in top 1
# INFO: Epoch 250, global step 12550: 'train_loss' was not in top 1
# INFO: Epoch 251, global step 12600: 'train_loss' was not in top 1
# INFO: Epoch 252, global step 12650: 'train_loss' was not in top 1
# INFO: Epoch 253, global step 12700: 'train_loss' was not in top 1
# INFO: Epoch 254, global step 12750: 'train_loss' was not in top 1
# INFO: Epoch 255, global step 12800: 'train_loss' was not in top 1
# INFO: Epoch 256, global step 12850: 'train_loss' was not in top 1
# INFO: Epoch 257, global step 12900: 'train_loss' was not in top 1
# INFO: Epoch 258, global step 12950: 'train_loss' was not in top 1
# INFO: Epoch 259, global step 13000: 'train_loss' was not in top 1
# INFO: Epoch 260, global step 13050: 'train_loss' was not in top 1
# INFO: Epoch 261, global step 13100: 'train_loss' was not in top 1
# INFO: Epoch 262, global step 13150: 'train_loss' was not in top 1
# INFO: Epoch 263, global step 13200: 'train_loss' was not in top 1
# INFO: Epoch 264, global step 13250: 'train_loss' was not in top 1
# INFO: Epoch 265, global step 13300: 'train_loss' was not in top 1
# INFO: Epoch 266, global step 13350: 'train_loss' was not in top 1
# INFO: Epoch 267, global step 13400: 'train_loss' was not in top 1
# INFO: Epoch 268, global step 13450: 'train_loss' was not in top 1
# INFO: Epoch 269, global step 13500: 'train_loss' was not in top 1
# INFO: Epoch 270, global step 13550: 'train_loss' was not in top 1
# INFO: Epoch 271, global step 13600: 'train_loss' was not in top 1
# INFO: Epoch 272, global step 13650: 'train_loss' was not in top 1
# INFO: Epoch 273, global step 13700: 'train_loss' was not in top 1
# INFO: Epoch 274, global step 13750: 'train_loss' was not in top 1
# INFO: Epoch 275, global step 13800: 'train_loss' was not in top 1
# INFO: Epoch 276, global step 13850: 'train_loss' was not in top 1
# INFO: Epoch 277, global step 13900: 'train_loss' was not in top 1
# INFO: Epoch 278, global step 13950: 'train_loss' was not in top 1
# INFO: Epoch 279, global step 14000: 'train_loss' was not in top 1
# INFO: Epoch 280, global step 14050: 'train_loss' was not in top 1
# INFO: Epoch 281, global step 14100: 'train_loss' was not in top 1
# INFO: Epoch 282, global step 14150: 'train_loss' was not in top 1
# INFO: Epoch 283, global step 14200: 'train_loss' was not in top 1
# INFO: Epoch 284, global step 14250: 'train_loss' was not in top 1
# INFO: Epoch 285, global step 14300: 'train_loss' was not in top 1
# INFO: Epoch 286, global step 14350: 'train_loss' was not in top 1
# INFO: Epoch 287, global step 14400: 'train_loss' was not in top 1
# INFO: Epoch 288, global step 14450: 'train_loss' was not in top 1
# INFO: Epoch 289, global step 14500: 'train_loss' was not in top 1
# INFO: Epoch 290, global step 14550: 'train_loss' was not in top 1
# INFO: Epoch 291, global step 14600: 'train_loss' was not in top 1
# INFO: Epoch 292, global step 14650: 'train_loss' was not in top 1
# INFO: Epoch 293, global step 14700: 'train_loss' was not in top 1
# INFO: Epoch 294, global step 14750: 'train_loss' was not in top 1
# INFO: Epoch 295, global step 14800: 'train_loss' was not in top 1
# INFO: Epoch 296, global step 14850: 'train_loss' was not in top 1
# INFO: Epoch 297, global step 14900: 'train_loss' was not in top 1
# INFO: Epoch 298, global step 14950: 'train_loss' was not in top 1
# INFO: Epoch 299, global step 15000: 'train_loss' was not in top 1
# INFO: `Trainer.fit` stopped: `max_epochs=300` reached.

# %%
ls /kaggle/working/lightning_logs/version_34/checkpoints
# Out:
# 'epoch=234-step=11750.ckpt'

# %%
# !cat Tourism_deepar_e300_optuna_in_1.json
# Out:
# [[[39847.734375, 14139.826171875, 8765.724609375, 10091.1318359375, 2853.386474609375, 3580.895263671875, 1424.3382568359375, 1084.356689453125, 3818.81884765625, 4502.72509765625, 2694.3583984375, 1521.8067626953125, 1717.99560546875, 759.3115234375, 3863.904052734375, 1185.2330322265625, 1487.930419921875, 1245.095458984375, 1130.4293212890625, 5641.70263671875, 1581.614013671875, 1955.6597900390625, 851.1113891601562, 1040.380615234375, 553.0516357421875, 471.6122741699219, 414.3499450683594, 2305.26416015625, 499.8637390136719, 334.80780029296875, 487.5422058105469, 362.82745361328125, 209.64340209960938, 523.8480834960938, 216.84962463378906, 3088.246826171875, 811.6580810546875, 1281.9310302734375, 3184.276611328125, 2495.029052734375, 564.0869750976562, 331.8970031738281, 495.3888854980469, 350.8620910644531, 669.4297485351562, 545.6260986328125, 276.2684020996094, 220.1829071044922, 667.1642456054688, 2078.16455078125, 722.2625732421875, 447.09490966796875, 867.1732788085938, 329.3132629394531, 387.34515380859375, 399.4686279296875, 279.7655334472656, 151.1368408203125, 449.4778137207031, 119.40746307373047, 93.25382995605469, 56.253875732421875, 46.604496002197266, 263.06463623046875, 91.48992156982422, 227.8998260498047, 61.626529693603516, 69.66874694824219, 125.438232421875, 152.671875, 1675.976806640625, 1653.3597412109375, 1327.3905029296875, 475.81793212890625, 227.351318359375, 299.3756103515625, 297.7547607421875, 285.06268310546875, 394.8127136230469, 862.6204833984375, 435.1690673828125, 242.88034057617188, 770.1822509765625, 50.07024383544922, 34.32714080810547, 166.56256103515625, 192.6359405517578, 46.66025924682617, 68.8075942993164, 96.97684478759766, 34.63469696044922, 189.8864288330078, 149.86424255371094, 155.30490112304688, 333.5591735839844, 977.1591186523438, 634.0286254882812, 360.261962890625, 256.6041259765625, 369.11932373046875, 91.74498748779297, 178.04591369628906, 122.38079833984375, 36.42648696899414, 263.4699401855469, 74.73392486572266, 65.05218505859375, 17.325252532958984, 39.14228057861328, 95.41368865966797, 17.515586853027344], [85007408.0, 11195890.0, 5325265.5, 4859031.0, 590880.375, 679413.3125, 253264.34375, 163707.421875, 691210.625, 1708685.875, 897264.75, 146368.640625, 171172.203125, 33428.91015625, 1026272.625, 195981.640625, 299910.28125, 105162.265625, 90133.859375, 2271603.5, 217400.125, 385933.0625, 61272.12890625, 81730.703125, 56630.60546875, 27263.580078125, 29297.125, 484031.875, 61233.71875, 18101.556640625, 45966.66796875, 28092.6015625, 10167.0068359375, 79286.7578125, 12528.7255859375, 378955.1875, 76313.515625, 125727.1328125, 1053253.625, 1015492.125, 64912.85546875, 10955.677734375, 29338.08203125, 16948.296875, 42241.69140625, 33965.546875, 18954.8671875, 5813.95068359375, 32339.333984375, 220434.453125, 183506.28125, 54907.5625, 192088.46875, 28051.62890625, 28654.25, 58187.5625, 13983.0341796875, 4171.52783203125, 30920.529296875, 2984.91259765625, 2376.8896484375, 984.0560302734375, 618.3630981445312, 9000.400390625, 1954.456298828125, 10049.6123046875, 936.0016479492188, 795.7967529296875, 2214.96533203125, 9447.7353515625, 243348.203125, 238757.796875, 240963.4375, 37767.49609375, 11035.978515625, 22861.189453125, 25697.5, 18407.18359375, 32349.998046875, 118992.3671875, 19303.177734375, 20441.15625, 54698.12109375, 585.5333862304688, 623.3226928710938, 7386.81298828125, 12051.6357421875, 1150.2132568359375, 1495.9306640625, 3153.92578125, 358.9537353515625, 7632.37939453125, 5190.005859375, 8109.2001953125, 22528.65234375, 63208.90625, 81441.203125, 41997.26171875, 12056.9501953125, 31855.794921875, 4073.488037109375, 7593.8662109375, 4731.19775390625, 467.41046142578125, 22015.412109375, 7576.91162109375, 2678.8486328125, 403.5579833984375, 935.9257202148438, 4228.4404296875, 480.6784362792969]], [[20204.267578125, 6449.57421875, 3686.801513671875, 5433.2060546875, 1378.6312255859375, 2043.6656494140625, 572.3052978515625, 410.851318359375, 1913.7044 ...
