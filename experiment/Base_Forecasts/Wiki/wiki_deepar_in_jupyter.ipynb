# %%
cd ../
# Out:
# d:\HierarchicalCode\experiment\Base_Forecasts

# %%
cd ../
# Out:
# d:\HierarchicalCode\experiment

# %%
import pandas as pd
import numpy as np
from sktime.forecasting.arima import AutoARIMA
import json
import time
import multiprocessing
from tqdm import tqdm
# import argparse

# parser = argparse.ArgumentParser()
# parser.add_argument('--dataset', type=str, default='Wiki', help='Type of dataset')

def Create_Data_Window(df,N,W,stride):
    '''
    Create W windows
    '''
    lis = []
    for i in range(W):
        lis.append(df.iloc[:(N+i*stride),:].reset_index().iloc[:,1:])
    return lis

def ARIMA_Prob_Forecast(series,h):
    '''
    Forecast h step using Auto_ARIMA method
    '''
    global num
    forecaster = AutoARIMA(sp=1,start_p=1,start_q=0, max_p=3, max_q=3,suppress_warnings=True) 
    forecaster.fit(series, fh=range(1,h+1))
    var_pred = forecaster.predict_var()
    var_pred = var_pred.iloc[:,0].tolist()
    mu_pred = forecaster.predict()
    mu_pred = mu_pred.tolist()
    resid = forecaster.predict_residuals().fillna(0).tolist()
    fitted = (resid + series).tolist()
    print('{}/199'.format(num))
    return [mu_pred,var_pred,resid,fitted]


# Get args
# args = parser.parse_args()
# dataset = args.dataset
dataset = 'Wiki'
st = time.time()
# Set the params
N = 351 # train size
h = 15   # forecast towards 12
N1 = 291
stride = 15
W = 4

# Load the raw data
data = pd.read_csv(f'./Data/{dataset}/{dataset}_process.csv').iloc[:N,:]

# For every variable, forecasting h = 15
# The first base forecast of validation set
forecast_results_in = []

# Create windows
data_windows = Create_Data_Window(data,N1,W,stride)
#print([df['T'][len(df)-1] for df in data_windows])

# pool = multiprocessing.Pool(processes=4) # 创建4个进程
# results = []
num = 1
print('Start.....')
for j in range(199):
    forecast_results_in.append(ARIMA_Prob_Forecast(data_windows[0].iloc[:,(j+1)],15))
# Out:
# Start.....
# 1/199
# 1/199
# 1/199
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 67
#      65 print('Start.....')
#      66 for j in range(199):
# ---> 67     forecast_results_in.append(ARIMA_Prob_Forecast(data_windows[0].iloc[:,(j+1)],15))
#
# Cell In[3], line 28, in ARIMA_Prob_Forecast(series, h)
#      26 global num
#      27 forecaster = AutoARIMA(sp=1,start_p=1,start_q=0, max_p=3, max_q=3,suppress_warnings=True)
# ---> 28 forecaster.fit(series, fh=range(1,h+1))
#      29 var_pred = forecaster.predict_var()
#      30 var_pred = var_pred.iloc[:,0].tolist()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sktime\forecasting\base\_base.py:387, in BaseForecaster.fit(self, y, X, fh)
# ...

# %%
def ARIMA_Prob_Forecast(series,h):
    '''
    Forecast h step using Auto_ARIMA method
    '''
    global num
    forecaster = AutoARIMA(sp=1,start_p=1,start_q=0, max_p=3, max_q=3,suppress_warnings=True) 
    forecaster.fit(series, fh=range(1,h+1))
    var_pred = forecaster.predict_var()
    var_pred = var_pred.iloc[:,0].tolist()
    mu_pred = forecaster.predict()
    mu_pred = mu_pred.tolist()
    resid = forecaster.predict_residuals().fillna(0).tolist()
    fitted = (resid + series).tolist()
    print('{}/199'.format(num))
    num += 1
    return [mu_pred,var_pred,resid,fitted]

# %%
# Get args
# args = parser.parse_args()
# dataset = args.dataset
dataset = 'Wiki'
st = time.time()
# Set the params
N = 351 # train size
h = 15   # forecast towards 12
N1 = 291
stride = 15
W = 4

# Load the raw data
data = pd.read_csv(f'./Data/{dataset}/{dataset}_process.csv').iloc[:N,:]

# For every variable, forecasting h = 15
# The first base forecast of validation set
forecast_results_in = []

# Create windows
data_windows = Create_Data_Window(data,N1,W,stride)
#print([df['T'][len(df)-1] for df in data_windows])

# pool = multiprocessing.Pool(processes=4) # 创建4个进程
# results = []
num = 1
print('Start.....')
for j in range(199):
    forecast_results_in.append(ARIMA_Prob_Forecast(data_windows[0].iloc[:,(j+1)],15))
# pool.close()
# pool.join()
# print ("Sub-process(es) done.")

# for res in results:
#     forecast_results_in.append(res.get())
# Out:
# Start.....
# 1/199
# 2/199
# 3/199
# 4/199
# 5/199
# 6/199
# 7/199
# 8/199
# 9/199
# 10/199
# 11/199
# 12/199
# 13/199
# 14/199
# 15/199
# 16/199
# 17/199
# 18/199
# 19/199
# 20/199
# 21/199
# 22/199
# 23/199
# 24/199
# 25/199
# 26/199
# 27/199
# 28/199
# 29/199
# 30/199
# 31/199
# 32/199
# 33/199
# 34/199
# 35/199
# 36/199
# 37/199
# 38/199
# 39/199
# 40/199
# 41/199
# 42/199
# 43/199
# 44/199
# 45/199
# 46/199
# 47/199
# 48/199
# 49/199
# 50/199
# 51/199
# 52/199
# 53/199
# 54/199
# 55/199
# 56/199
# 57/199
# 58/199
# 59/199
# 60/199
# 61/199
# 62/199
# 63/199
# 64/199
# 65/199
# 66/199
# 67/199
# 68/199
# 69/199
# 70/199
# 71/199
# 72/199
# 73/199
# 74/199
# 75/199
# 76/199
# 77/199
# 78/199
# 79/199
# 80/199
# 81/199
# 82/199
# 83/199
# 84/199
# 85/199
# 86/199
# 87/199
# 88/199
# 89/199
# 90/199
# 91/199
# 92/199
# 93/199
# 94/199
# 95/199
# 96/199
# 97/199
# 98/199
# 99/199
# 100/199
# 101/199
# 102/199
# 103/199
# 104/199
# ...

# %%
forecast_results_in[131]
# Out:
# [[84.8675813297079,
#   149.41778266565265,
#   290.9016295998035,
#   485.86770170806284,
#   712.4526953523648,
#   951.3237859943036,
#   1186.2878359943984,
#   1404.5986750775926,
#   1597.004844820978,
#   1757.5867013824882,
#   1883.4341654638547,
#   1974.21537477698,
#   2031.6827737561919,
#   2059.1575166853954,
#   2061.026175104288],
#  [1030814.0822672186,
#   6382728.151402578,
#   16751764.932159014,
#   30897122.133436266,
#   46720491.00177784,
#   62107237.04162599,
#   75448407.00492309,
#   85855639.52915815,
#   93138544.71991958,
#   97636978.31756897,
#   99996581.51758355,
#   100955434.1227743,
#   101182744.07389878,
#   101184940.35022113,
#   101275058.31440364],
#  [16854.748507341472,
#   -17252.967234388176,
#   15289.034623469894,
#   -6479.331589152148,
#   3243.467278733331,
#   -1756.2680625314654,
#   862.1080117092423,
#   -603.5758198639757,
#   311.38965134661476,
#   -260.68594644557646,
#   -34.355893185576804,
#   -25.197957717183385,
# ...

# %%
forecast_results_in[130]
# Out:
# [[872.0448601605617,
#   891.8703007787956,
#   880.4148796924069,
#   876.5226709674802,
#   879.2185167988573,
#   879.9636524801009,
#   879.3364919509361,
#   879.1985625698336,
#   879.3429591807748,
#   879.3672874400311,
#   879.3343575630968,
#   879.3303836855599,
#   879.3378264708264,
#   879.3383878373927,
#   879.336719943631],
#  [10319.034885220732,
#   11147.828600647455,
#   11237.037090616132,
#   11931.18821780487,
#   12825.25897985902,
#   13502.117769260934,
#   14147.102807058767,
#   14837.791457754278,
#   15533.711585690657,
#   16219.141714414232,
#   16903.867301208516,
#   17590.931965764463,
#   18278.052955343155,
#   18964.654510661512,
#   19651.26570766929],
#  [0.0,
#   52.979766153553896,
#   51.654322075805226,
#   -54.517402128324534,
#   -153.64815901913732,
#   -23.44260936548585,
#   -64.35982282301461,
#   6.213516545001198,
#   51.618529139044426,
#   83.12611817041443,
#   -145.8265541044924,
#   -14.56650302007381,
# ...

# %%
num = 1
print('Start.....')
for j in range(199):
    forecast_results_in.append(ARIMA_Prob_Forecast(data_windows[1].iloc[:,(j+1)],15))
# Out:
# Start.....
# 1/199
# 2/199
# 3/199
# 4/199
# 5/199
# 6/199
# 7/199
# 8/199
# 9/199
# 10/199
# 11/199
# 12/199
# 13/199
# 14/199
# 15/199
# 16/199
# 17/199
# 18/199
# 19/199
# 20/199
# 21/199
# 22/199
# 23/199
# 24/199
# 25/199
# 26/199
# 27/199
# 28/199
# 29/199
# 30/199
# 31/199
# 32/199
# 33/199
# 34/199
# 35/199
# 36/199
# 37/199
# 38/199
# 39/199
# 40/199
# 41/199
# 42/199
# 43/199
# 44/199
# 45/199
# 46/199
# 47/199
# 48/199
# 49/199
# 50/199
# 51/199
# 52/199
# 53/199
# 54/199
# 55/199
# 56/199
# 57/199
# 58/199
# 59/199
# 60/199
# 61/199
# 62/199
# 63/199
# 64/199
# 65/199
# 66/199
# 67/199
# 68/199
# 69/199
# 70/199
# 71/199
# 72/199
# 73/199
# 74/199
# 75/199
# 76/199
# 77/199
# 78/199
# 79/199
# 80/199
# 81/199
# 82/199
# 83/199
# 84/199
# 85/199
# 86/199
# 87/199
# 88/199
# 89/199
# 90/199
# 91/199
# 92/199
# 93/199
# 94/199
# 95/199
# 96/199
# 97/199
# 98/199
# 99/199
# 100/199
# 101/199
# 102/199
# 103/199
# 104/199
# ...

# %%
len(forecast_results_in)
# Out:
# 398

# %%
len(forecast_results_in[0])
# Out:
# 4

# %%
len(forecast_results_in[0][0])
# Out:
# 15

# %%
forecast_results_in[0][0]
# Out:
# [95593.87727394866,
#  99289.52710701435,
#  99289.52710701435,
#  99289.52710701435,
#  99289.52710701435,
#  99289.52710701435,
#  99289.52710701435,
#  99289.52710701435,
#  99289.52710701435,
#  99289.52710701435,
#  99289.52710701435,
#  99289.52710701435,
#  99289.52710701435,
#  99289.52710701435,
#  99289.52710701435]

# %%
forecast_results_in[0][1]
# Out:
# [1142469691.0777762,
#  1305288894.9902759,
#  1307951272.6111248,
#  1310613650.2319753,
#  1313276027.8528247,
#  1315938405.473674,
#  1318600783.0945241,
#  1321263160.715375,
#  1323925538.3362248,
#  1326587915.957074,
#  1329250293.577924,
#  1331912671.1987731,
#  1334575048.8196244,
#  1337237426.4404736,
#  1339899804.0613227]

# %%
forecast_results_in[0][2]
# Out:
# [0.0,
#  17053.905616725693,
#  49025.13579968079,
#  2279.388473522762,
#  25172.99058979044,
#  24720.07003476641,
#  44837.024096475725,
#  -7032.708670607681,
#  34381.582320234826,
#  659.0107489583897,
#  41190.52922547214,
#  -15668.321656201646,
#  15172.258460687997,
#  -8417.728434743258,
#  -1427.4115057599993,
#  28394.06835056693,
#  63438.17160297037,
#  -18156.877119710844,
#  -16694.331133683532,
#  -14832.818489355981,
#  -19099.748610694514,
#  41219.81387153233,
#  -18589.510785824765,
#  3150.157406395272,
#  -21848.953305730145,
#  -19691.050512216607,
#  -11116.706877002172,
#  -19953.231216355314,
#  -17003.302443924724,
#  23778.366486290877,
#  74.33699470982538,
#  -10334.193989402935,
#  2786.4545713117986,
#  17873.709899410373,
#  -24384.301630523347,
#  -16079.873504190211,
#  13761.951028922485,
#  1070.2890944780956,
#  -6879.174693732522,
#  5994.906300065937,
#  51092.17298851644,
#  -24563.32037664717,
#  -15866.858912736934,
#  126796.65813734304,
# ...

# %%
forecast_results_in[1][0]
# Out:
# [11743.218209097296,
#  13684.836260705619,
#  14641.36301419252,
#  15112.590313185907,
#  15344.737680216811,
#  15459.103719991042,
#  15515.445479197382,
#  15543.201916656715,
#  15556.875962893228,
#  15563.612401629367,
#  15566.931068691101,
#  15568.565990568673,
#  15569.37142524954,
#  15569.768217924491,
#  15569.963695510243]

# %%
forecast_results_in[2][0]
# Out:
# [40593.673223941056,
#  40907.056773406766,
#  41090.952984522984,
#  41198.86489157924,
#  41262.18854362097,
#  41299.34741716226,
#  41321.15256955536,
#  41333.94802392665,
#  41341.456508601106,
#  41345.86255315964,
#  41348.44805869018,
#  41349.965255976684,
#  41350.85556063046,
#  41351.37799919766,
#  41351.684570723875]

# %%
forecast_results_in[2][1]
# Out:
# [215415737.37421742,
#  244659396.85105842,
#  258473903.92587188,
#  265896917.9263678,
#  270486154.3088676,
#  273728202.45739263,
#  276288417.3830222,
#  278485959.82341313,
#  280483572.797882,
#  282368303.9857424,
#  284188323.5516051,
#  285970896.06677854,
#  287731675.5517504,
#  289479729.10030514,
#  291220336.4465932]

# %%
num = 1
print('Start.....')
for j in range(199):
    forecast_results_in.append(ARIMA_Prob_Forecast(data_windows[2].iloc[:,(j+1)],15))
# Out:
# Start.....
# 1/199
# 2/199
# 3/199
# 4/199
# 5/199
# 6/199
# 7/199
# 8/199
# 9/199
# 10/199
# 11/199
# 12/199
# 13/199
# 14/199
# 15/199
# 16/199
# 17/199
# 18/199
# 19/199
# 20/199
# 21/199
# 22/199
# 23/199
# 24/199
# 25/199
# 26/199
# 27/199
# 28/199
# 29/199
# 30/199
# 31/199
# 32/199
# 33/199
# 34/199
# 35/199
# 36/199
# 37/199
# 38/199
# 39/199
# 40/199
# 41/199
# 42/199
# 43/199
# 44/199
# 45/199
# 46/199
# 47/199
# 48/199
# 49/199
# 50/199
# 51/199
# 52/199
# 53/199
# 54/199
# 55/199
# 56/199
# 57/199
# 58/199
# 59/199
# 60/199
# 61/199
# 62/199
# 63/199
# 64/199
# 65/199
# 66/199
# 67/199
# 68/199
# 69/199
# 70/199
# 71/199
# 72/199
# 73/199
# 74/199
# 75/199
# 76/199
# 77/199
# 78/199
# 79/199
# 80/199
# 81/199
# 82/199
# 83/199
# 84/199
# 85/199
# 86/199
# 87/199
# 88/199
# 89/199
# 90/199
# 91/199
# 92/199
# 93/199
# 94/199
# 95/199
# 96/199
# 97/199
# 98/199
# 99/199
# 100/199
# 101/199
# 102/199
# 103/199
# 104/199
# 105/199
# 106/199
# 107/199
# 108/199
# 109/199
# ...

# %%
with open(f'./Base_Forecasts/{dataset}/{dataset}_in.json','w') as file:
    file.write(json.dumps(forecast_results_in))

# %%
num = 1
print('Start.....')
for j in range(199):
    forecast_results_in.append(ARIMA_Prob_Forecast(data_windows[3].iloc[:,(j+1)],15))
# Out:
# Start.....
# 1/199
# 2/199
# 3/199
# 4/199
# 5/199
# 6/199
# 7/199
# 8/199
# 9/199
# 10/199
# 11/199
# 12/199
# 13/199
# 14/199
# 15/199
# 16/199
# 17/199
# 18/199
# 19/199
# 20/199
# 21/199
# 22/199
# 23/199
# 24/199
# 25/199
# 26/199
# 27/199
# 28/199
# 29/199
# 30/199
# 31/199
# 32/199
# 33/199
# 34/199
# 35/199
# 36/199
# 37/199
# 38/199
# 39/199
# 40/199
# 41/199
# 42/199
# 43/199
# 44/199
# 45/199
# 46/199
# 47/199
# 48/199
# 49/199
# 50/199
# 51/199
# 52/199
# 53/199
# 54/199
# 55/199
# 56/199
# 57/199
# 58/199
# 59/199
# 60/199
# 61/199
# 62/199
# 63/199
# 64/199
# 65/199
# 66/199
# 67/199
# 68/199
# 69/199
# 70/199
# 71/199
# 72/199
# 73/199
# 74/199
# 75/199
# 76/199
# 77/199
# 78/199
# 79/199
# 80/199
# 81/199
# 82/199
# 83/199
# 84/199
# 85/199
# 86/199
# 87/199
# 88/199
# 89/199
# 90/199
# 91/199
# 92/199
# 93/199
# 94/199
# 95/199
# 96/199
# 97/199
# 98/199
# 99/199
# 100/199
# 101/199
# 102/199
# 103/199
# 104/199
# ...

# %%
len(forecast_results_in)
# Out:
# 701

# %%
a = ARIMA_Prob_Forecast(data_windows[3].iloc[:,104],15)
# Out:
# 105/199

# %%
a
# Out:
# [[1237.0741931429386,
#   1216.1800681131317,
#   1136.3064312357312,
#   1126.0554540571557,
#   1114.1468476567811,
#   1099.0444338512445,
#   1091.4131952585153,
#   1086.0814023479484,
#   1081.7060156361808,
#   1078.7786717392628,
#   1076.735685146779,
#   1075.2363779377743,
#   1074.179030003737,
#   1073.4320004079916,
#   1072.8973194457155],
#  [112059.94164184929,
#   127013.95169302038,
#   131621.37855472325,
#   137300.18375196768,
#   139566.66789146198,
#   140536.91328072606,
#   141120.275351656,
#   141408.1745360302,
#   141547.14639998568,
#   141619.7219114509,
#   141656.47486794737,
#   141674.8552835722,
#   141684.20307681002,
#   141688.93911731784,
#   141691.32899250527],
#  [374.4178798761948,
#   264.25807494520495,
#   256.9044072232523,
#   566.9326430128842,
#   -242.90009842513336,
#   -170.9657751651439,
#   -248.34316582465772,
#   -24.09792359838184,
#   104.76160646768108,
#   230.01210210693625,
#   44.56843773610149,
# ...

# %%
forecast_results_in[-1]
# Out:
# [[1237.0741931429386,
#   1216.1800681131317,
#   1136.3064312357312,
#   1126.0554540571557,
#   1114.1468476567811,
#   1099.0444338512445,
#   1091.4131952585153,
#   1086.0814023479484,
#   1081.7060156361808,
#   1078.7786717392628,
#   1076.735685146779,
#   1075.2363779377743,
#   1074.179030003737,
#   1073.4320004079916,
#   1072.8973194457155],
#  [112059.94164184929,
#   127013.95169302038,
#   131621.37855472325,
#   137300.18375196768,
#   139566.66789146198,
#   140536.91328072606,
#   141120.275351656,
#   141408.1745360302,
#   141547.14639998568,
#   141619.7219114509,
#   141656.47486794737,
#   141674.8552835722,
#   141684.20307681002,
#   141688.93911731784,
#   141691.32899250527],
#  [374.4178798761948,
#   264.25807494520495,
#   256.9044072232523,
#   566.9326430128842,
#   -242.90009842513336,
#   -170.9657751651439,
#   -248.34316582465772,
#   -24.09792359838184,
#   104.76160646768108,
#   230.01210210693625,
#   44.56843773610149,
# ...

# %%
a = ARIMA_Prob_Forecast(data_windows[3].iloc[:,105],15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 a = ARIMA_Prob_Forecast(data_windows[3].iloc[:,105],15)
#
# Cell In[4], line 8, in ARIMA_Prob_Forecast(series, h)
#       6 forecaster = AutoARIMA(sp=1,start_p=1,start_q=0, max_p=3, max_q=3,suppress_warnings=True)
#       7 forecaster.fit(series, fh=range(1,h+1))
# ----> 8 var_pred = forecaster.predict_var()
#       9 var_pred = var_pred.iloc[:,0].tolist()
#      10 mu_pred = forecaster.predict()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sktime\forecasting\base\_base.py:795, in BaseForecaster.predict_var(self, fh, X, cov)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=792'>793</a> # we call the ordinary _predict_interval if no looping/vectorization needed
# ...

# %%
forecast_results_in[-1][0]
# Out:
# [1237.0741931429386,
#  1216.1800681131317,
#  1136.3064312357312,
#  1126.0554540571557,
#  1114.1468476567811,
#  1099.0444338512445,
#  1091.4131952585153,
#  1086.0814023479484,
#  1081.7060156361808,
#  1078.7786717392628,
#  1076.735685146779,
#  1075.2363779377743,
#  1074.179030003737,
#  1073.4320004079916,
#  1072.8973194457155]

# %%
forecast_results_in[-1][1]
# Out:
# [112059.94164184929,
#  127013.95169302038,
#  131621.37855472325,
#  137300.18375196768,
#  139566.66789146198,
#  140536.91328072606,
#  141120.275351656,
#  141408.1745360302,
#  141547.14639998568,
#  141619.7219114509,
#  141656.47486794737,
#  141674.8552835722,
#  141684.20307681002,
#  141688.93911731784,
#  141691.32899250527]

# %%
forecast_results_in[-1][2]
# Out:
# [374.4178798761948,
#  264.25807494520495,
#  256.9044072232523,
#  566.9326430128842,
#  -242.90009842513336,
#  -170.9657751651439,
#  -248.34316582465772,
#  -24.09792359838184,
#  104.76160646768108,
#  230.01210210693625,
#  44.56843773610149,
#  -34.04354376427568,
#  -227.1148735092088,
#  4.3856510134528435,
#  -28.48447594240747,
#  189.6570492149133,
#  106.53936432852765,
#  -23.68673022851749,
#  -168.42453679282858,
#  -107.83244398843954,
#  -92.82695015743025,
#  -64.29580709473066,
#  218.26379588342456,
#  205.67461362773247,
#  -156.76379868226422,
#  -205.1419421941648,
#  221.9959120239298,
#  -226.97092825813525,
#  -88.23332279128044,
#  69.25504215006367,
#  365.3191473905365,
#  349.2649679495689,
#  -290.6772606267466,
#  -268.30100513427146,
#  909.2371269123169,
#  -285.3108294177341,
#  395.93485031854766,
#  422.24475515099584,
#  -392.8786989813591,
#  -256.9644530407934,
#  -225.14135562447314,
#  -162.6380607479589,
#  -24.431167976200413,
# ...

# %%
forecast_results_in[-1][3]
# Out:
# [1820.4178798761948,
#  1761.258074945205,
#  1790.9044072232523,
#  2450.932643012884,
#  968.0999015748666,
#  895.0342248348561,
#  684.6568341753423,
#  989.9020764016182,
#  1249.761606467681,
#  1537.0121021069363,
#  1244.5684377361015,
#  1075.9564562357243,
#  669.8851264907912,
#  1035.3856510134528,
#  992.5155240575925,
#  1407.6570492149133,
#  1329.5393643285277,
#  1083.3132697714825,
#  776.5754632071714,
#  831.1675560115605,
#  833.1730498425698,
#  864.7041929052693,
#  1429.2637958834246,
#  1505.6746136277325,
#  833.2362013177358,
#  664.8580578058352,
#  1464.9959120239298,
#  656.0290717418648,
#  812.7666772087196,
#  1156.2550421500637,
#  1772.3191473905365,
#  1872.264967949569,
#  680.3227393732534,
#  571.6989948657285,
#  2855.237126912317,
#  791.6891705822659,
#  1896.9348503185477,
#  2183.244755150996,
#  568.1213010186409,
#  619.0355469592066,
#  628.8586443755269,
#  639.3619392520411,
#  884.5688320237996,
#  1009.85199174429,
# ...

# %%
data_windows[3].iloc[:,105]
# Out:
# 0      2826
# 1      3124
# 2      5622
# 3      3125
# 4      2793
#        ...
# 331    1350
# 332     494
# 333     426
# 334     375
# 335     415
# Name: fr_AAC_AAG_098, Length: 336, dtype: int64

# %%
data_windows[3].iloc[:,105].any()
# Out:
# True

# %%
data_windows[3].iloc[:,105].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 331    False
# 332    False
# 333    False
# 334    False
# 335    False
# Name: fr_AAC_AAG_098, Length: 336, dtype: bool

# %%
data_windows[3].iloc[:,105].isnull().sum()
# Out:
# 0

# %%
data_windows[3].iloc[:,105] = data_windows[3].iloc[:,105].astype(float)
a = ARIMA_Prob_Forecast(data_windows[3].iloc[:,105],15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 data_windows[3].iloc[:,105] = data_windows[3].iloc[:,105].astype(float)
# ----> 2 a = ARIMA_Prob_Forecast(data_windows[3].iloc[:,105],15)
#
# Cell In[4], line 8, in ARIMA_Prob_Forecast(series, h)
#       6 forecaster = AutoARIMA(sp=1,start_p=1,start_q=0, max_p=3, max_q=3,suppress_warnings=True)
#       7 forecaster.fit(series, fh=range(1,h+1))
# ----> 8 var_pred = forecaster.predict_var()
#       9 var_pred = var_pred.iloc[:,0].tolist()
#      10 mu_pred = forecaster.predict()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sktime\forecasting\base\_base.py:795, in BaseForecaster.predict_var(self, fh, X, cov)
# ...

# %%
import statsmodels.api as sm

# 假设 'endog' 是时间序列数据
model = sm.tsa.ARIMA(data_windows[3].iloc[:,105], order=(1,1,1))
results = model.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:         fr_AAC_AAG_098   No. Observations:                  336
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -2316.436
# Date:                Tue, 07 May 2024   AIC                           4638.872
# Time:                        19:04:43   BIC                           4650.314
# Sample:                             0   HQIC                          4643.434
#                                 - 336
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3676      0.030     12.359      0.000       0.309       0.426
# ma.L1         -0.8124      0.034    -23.682      0.000      -0.880      -0.745
# sigma2      5.917e+04   1376.248     42.994      0.000    5.65e+04    6.19e+04
# ...

# %%
params_cov = results.cov_params()

# %%
params_cov
# Out:
#             ar.L1      ma.L1        sigma2
# ar.L1    0.000885  -0.000832 -1.273605e+01
# ma.L1   -0.000832   0.001177  2.687439e+01
# sigma2 -12.736048  26.874390  1.894059e+06

# %%
 res=results.predict(start=336, end=350)

# %%
res
# Out:
# 336    476.855457
# 337    499.594953
# 338    507.954517
# 339    511.027685
# 340    512.157453
# 341    512.572782
# 342    512.725467
# 343    512.781597
# 344    512.802232
# 345    512.809818
# 346    512.812606
# 347    512.813631
# 348    512.814008
# 349    512.814147
# 350    512.814198
# Name: predicted_mean, dtype: float64

# %%
res_mean = res.tolist()

# %%
res_mean
# Out:
# [476.85545734026437,
#  499.59495269756013,
#  507.954516612188,
#  511.0276854642103,
#  512.157453343192,
#  512.5727821200467,
#  512.725466575051,
#  512.7815969086544,
#  512.8022317162406,
#  512.8098175482995,
#  512.8126062754434,
#  512.8136314759781,
#  512.8140083633831,
#  512.8141469159016,
#  512.8141978510088]

# %%
res_var = results.forecast_var(start=336, end=350)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 res_var = results.forecast_var(start=336, end=350)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:34, in ResultsWrapper.__getattribute__(self, attr)
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/statsmodels/base/wrapper.py?line=30'>31</a> except AttributeError:
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/statsmodels/base/wrapper.py?line=31'>32</a>     pass
# ---> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/statsmodels/base/wrapper.py?line=33'>34</a> obj = getattr(results, attr)
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/statsmodels/base/wrapper.py?line=34'>35</a> data = results.model.data
# ...

# %%
interval = results.predict(start=336, end=350, confidence_level=0.95)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['confidence_level']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)

# %%
interval
# Out:
# 336    476.855457
# 337    499.594953
# 338    507.954517
# 339    511.027685
# 340    512.157453
# 341    512.572782
# 342    512.725467
# 343    512.781597
# 344    512.802232
# 345    512.809818
# 346    512.812606
# 347    512.813631
# 348    512.814008
# 349    512.814147
# 350    512.814198
# Name: predicted_mean, dtype: float64

# %%
m,interval = results.predict(start=336, end=350, typ='confidence')
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 m,interval = results.predict(start=336, end=350, typ='confidence')
#
# ValueError: too many values to unpack (expected 2)

# %%
interval = results.predict(start=336, end=350, typ='confidence')

# %%
interval
# Out:
# 336    476.855457
# 337    499.594953
# 338    507.954517
# 339    511.027685
# 340    512.157453
# 341    512.572782
# 342    512.725467
# 343    512.781597
# 344    512.802232
# 345    512.809818
# 346    512.812606
# 347    512.813631
# 348    512.814008
# 349    512.814147
# 350    512.814198
# Name: predicted_mean, dtype: float64

# %%
interval = results.predict(start=336, end=350, typ='confidence',alpha=0.05)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['typ', 'alpha']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)

# %%
interval, conf= results.predict(start=336, end=350, typ='confidence',alpha=0.05)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 interval, conf= results.predict(start=336, end=350, typ='confidence',alpha=0.05)
#
# ValueError: too many values to unpack (expected 2)

# %%
interval[:,2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 interval[:,2]
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:966, in Series.__getitem__(self, key)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/pandas/core/series.py?line=962'>963</a>     key = np.asarray(key, dtype=bool)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/pandas/core/series.py?line=963'>964</a>     return self._get_values(key)
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/pandas/core/series.py?line=965'>966</a> return self._get_with(key)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:981, in Series._get_with(self, key)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/pandas/core/series.py?line=975'>976</a>     raise TypeError(
# ...

# %%
interval[1,:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 interval[1,:]
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:966, in Series.__getitem__(self, key)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/pandas/core/series.py?line=962'>963</a>     key = np.asarray(key, dtype=bool)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/pandas/core/series.py?line=963'>964</a>     return self._get_values(key)
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/pandas/core/series.py?line=965'>966</a> return self._get_with(key)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:981, in Series._get_with(self, key)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/pandas/core/series.py?line=975'>976</a>     raise TypeError(
# ...

# %%
# predict 方法返回的是一个 DataFrame，包括预测值和置信区间
prediction_results = results.predict(start=336, end=350, typ='confidence', alpha=0.05)

# 从预测结果中提取预测值和置信区间的上下限
预测值 = prediction_results['mean']
置信区间下限 = prediction_results['lower %f' % (1 - alpha)]
置信区间上限 = prediction_results['upper %f' % (1 - alpha)]

# 估计预测值的方差，这里我们假设置信区间代表正态分布的2个标准差
预测方差 = (置信区间上限 - 置信区间下限) ** 2 / (4 * (1 - alpha))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 5
#       2 prediction_results = results.predict(start=336, end=350, typ='confidence', alpha=0.05)
#       4 # 从预测结果中提取预测值和置信区间的上下限
# ----> 5 预测值 = prediction_results['mean']
#       6 置信区间下限 = prediction_results['lower %f' % (1 - alpha)]
#       7 置信区间上限 = prediction_results['upper %f' % (1 - alpha)]
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:942, in Series.__getitem__(self, key)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/pandas/core/series.py?line=938'>939</a>     return self._values[key]
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/pandas/core/series.py?line=940'>941</a> elif key_is_scalar:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/pandas/core/series.py?line=941'>942</a>     return self._get_value(key)
# ...

# %%
prediction_results
# Out:
# 336    476.855457
# 337    499.594953
# 338    507.954517
# 339    511.027685
# 340    512.157453
# 341    512.572782
# 342    512.725467
# 343    512.781597
# 344    512.802232
# 345    512.809818
# 346    512.812606
# 347    512.813631
# 348    512.814008
# 349    512.814147
# 350    512.814198
# Name: predicted_mean, dtype: float64

# %%
interval = results.predict(start=336, end=350, typ='confidence',return_conf_int=True)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['typ', 'return_conf_int']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)

# %%
interval
# Out:
# 336    476.855457
# 337    499.594953
# 338    507.954517
# 339    511.027685
# 340    512.157453
# 341    512.572782
# 342    512.725467
# 343    512.781597
# 344    512.802232
# 345    512.809818
# 346    512.812606
# 347    512.813631
# 348    512.814008
# 349    512.814147
# 350    512.814198
# Name: predicted_mean, dtype: float64

# %%
interval,ci= results.predict(start=336, end=350, typ='confidence',return_conf_int=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 interval,ci= results.predict(start=336, end=350, typ='confidence',return_conf_int=True)
#
# ValueError: too many values to unpack (expected 2)

# %%
    forecaster = AutoARIMA(sp=1,start_p=1,start_q=0, max_p=3, max_q=3,suppress_warnings=True) 
    forecaster.fit(data_windows[3].iloc[:,105], fh=range(1,h+1))
# Out:
# AutoARIMA(max_p=3, max_q=3, start_p=1, start_q=0, suppress_warnings=True)

# %%
forecaster.predict_var()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 forecaster.predict_var()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sktime\forecasting\base\_base.py:795, in BaseForecaster.predict_var(self, fh, X, cov)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=792'>793</a> # we call the ordinary _predict_interval if no looping/vectorization needed
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=793'>794</a> if not self._is_vectorized:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=794'>795</a>     pred_var = self._predict_var(fh=fh, X=X_inner, cov=cov)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=795'>796</a> else:
# ...

# %%
data_windows[3].iloc[:,105].summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-72c0eda899de> in ?()
# ----> 1 data_windows[3].iloc[:,105].summary()
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5483             and name not in self._accessors
#    5484             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'summary'

# %%
data_windows[3].iloc[:,105].max()
# Out:
# 5622.0

# %%
data_windows[3].iloc[:,105].min()
# Out:
# 329.0

# %%
    forecaster = AutoARIMA(sp=1,start_p=1,start_q=0, max_p=3, max_q=3,suppress_warnings=True) 
    forecaster.fit(data_windows[3].iloc[:,106], fh=range(1,h+1))
# Out:
# AutoARIMA(max_p=3, max_q=3, start_p=1, start_q=0, suppress_warnings=True)

# %%
forecaster.predict_var()
# Out:
#      fr_AAC_AAG_104
# 336    54680.797848
# 337    81870.419959
# 338    98328.851928
# 339   110179.124800
# 340   119889.882690
# 341   128551.299421
# 342   136680.016051
# 343   144532.802233
# 344   152241.038440
# 345   159873.081561
# 346   167464.829054
# 347   175035.227732
# 348   182594.304959
# 349   190147.375294
# 350   197697.257657

# %%
    forecaster = AutoARIMA(sp=1,start_p=1,start_q=0, max_p=3, max_q=3,suppress_warnings=True) 
    forecaster.fit(data_windows[3].iloc[:,105], fh=range(1,h+1))
# Out:
# AutoARIMA(max_p=3, max_q=3, start_p=1, start_q=0, suppress_warnings=True)

# %%
forecaster.predict()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 forecaster.predict()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sktime\forecasting\base\_base.py:444, in BaseForecaster.predict(self, fh, X)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=441'>442</a> # we call the ordinary _predict if no looping/vectorization needed
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=442'>443</a> if not self._is_vectorized:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=443'>444</a>     y_pred = self._predict(fh=fh, X=X_inner)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=444'>445</a> else:
# ...

# %%
data_windows[3].iloc[:,105].tolist()
# Out:
# [2826.0,
#  3124.0,
#  5622.0,
#  3125.0,
#  2793.0,
#  2251.0,
#  1896.0,
#  1767.0,
#  2098.0,
#  2789.0,
#  2750.0,
#  2881.0,
#  1944.0,
#  1800.0,
#  1632.0,
#  1676.0,
#  2497.0,
#  2024.0,
#  1880.0,
#  1546.0,
#  1476.0,
#  1267.0,
#  1424.0,
#  2050.0,
#  1646.0,
#  1370.0,
#  1294.0,
#  1089.0,
#  1158.0,
#  1303.0,
#  1607.0,
#  1181.0,
#  1155.0,
#  1054.0,
#  929.0,
#  783.0,
#  965.0,
#  1247.0,
#  1000.0,
#  948.0,
#  825.0,
#  802.0,
#  771.0,
#  964.0,
#  1242.0,
#  991.0,
#  748.0,
#  897.0,
#  805.0,
#  693.0,
#  798.0,
#  1029.0,
#  790.0,
#  968.0,
#  810.0,
#  732.0,
#  641.0,
#  999.0,
#  1404.0,
#  862.0,
#  737.0,
#  765.0,
#  800.0,
#  811.0,
#  994.0,
#  1101.0,
#  786.0,
#  699.0,
#  761.0,
#  645.0,
#  596.0,
#  898.0,
#  982.0,
#  751.0,
#  635.0,
#  640.0,
#  935.0,
#  707.0,
#  847.0,
#  1082.0,
#  724.0,
#  558.0,
#  634.0,
#  538.0,
#  638.0,
#  789.0,
#  883.0,
#  900.0,
#  656.0,
#  615.0,
#  616.0,
#  529.0,
#  647.0,
#  746.0,
#  654.0,
# ...

# %%
data_windows[3].iloc[:,105].fillna(0)
# Out:
# 0      2826.0
# 1      3124.0
# 2      5622.0
# 3      3125.0
# 4      2793.0
#         ...
# 331    1350.0
# 332     494.0
# 333     426.0
# 334     375.0
# 335     415.0
# Name: fr_AAC_AAG_098, Length: 336, dtype: float64

# %%
data_windows[3].iloc[:,105]=data_windows[3].iloc[:,105].fillna(0)

# %%
    forecaster = AutoARIMA(sp=1,start_p=1,start_q=0, max_p=3, max_q=3,suppress_warnings=True) 
    forecaster.fit(data_windows[3].iloc[:,106], fh=range(1,h+1))
# Out:
# AutoARIMA(max_p=3, max_q=3, start_p=1, start_q=0, suppress_warnings=True)

# %%
    forecaster = AutoARIMA(sp=1,start_p=1,start_q=0, max_p=3, max_q=3,suppress_warnings=True) 
    forecaster.fit(data_windows[3].iloc[:,105], fh=range(1,h+1))
# Out:
# AutoARIMA(max_p=3, max_q=3, start_p=1, start_q=0, suppress_warnings=True)

# %%
forecaster.predict()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 forecaster.predict()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sktime\forecasting\base\_base.py:444, in BaseForecaster.predict(self, fh, X)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=441'>442</a> # we call the ordinary _predict if no looping/vectorization needed
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=442'>443</a> if not self._is_vectorized:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=443'>444</a>     y_pred = self._predict(fh=fh, X=X_inner)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=444'>445</a> else:
# ...

# %%
endog = pd.to_numeric(data_windows[3].iloc[:,105], errors='coerce')

# %%
endog
# Out:
# 0      2826.0
# 1      3124.0
# 2      5622.0
# 3      3125.0
# 4      2793.0
#         ...
# 331    1350.0
# 332     494.0
# 333     426.0
# 334     375.0
# 335     415.0
# Name: fr_AAC_AAG_098, Length: 336, dtype: float64

# %%
    forecaster = AutoARIMA(sp=1,start_p=1,start_q=0, max_p=3, max_q=3,suppress_warnings=True) 
    forecaster.fit(endog, fh=range(1,h+1))
# Out:
# AutoARIMA(max_p=3, max_q=3, start_p=1, start_q=0, suppress_warnings=True)

# %%
forecaster.predict()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 forecaster.predict()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sktime\forecasting\base\_base.py:444, in BaseForecaster.predict(self, fh, X)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=441'>442</a> # we call the ordinary _predict if no looping/vectorization needed
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=442'>443</a> if not self._is_vectorized:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=443'>444</a>     y_pred = self._predict(fh=fh, X=X_inner)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=444'>445</a> else:
# ...

# %%
print(pd.isnull(endog).any())  # 查找 NaN 值
print(np.isinf(endog).any())  # 查找无穷值
# Out:
# False
# False

# %%
endog = endog.astype('float64')

# %%
    forecaster = AutoARIMA(sp=1,start_p=1,start_q=0, max_p=3, max_q=3,suppress_warnings=True) 
    forecaster.fit(endog, fh=range(1,h+1))
# Out:
# AutoARIMA(max_p=3, max_q=3, start_p=1, start_q=0, suppress_warnings=True)

# %%
forecaster.predict()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 forecaster.predict()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sktime\forecasting\base\_base.py:444, in BaseForecaster.predict(self, fh, X)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=441'>442</a> # we call the ordinary _predict if no looping/vectorization needed
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=442'>443</a> if not self._is_vectorized:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=443'>444</a>     y_pred = self._predict(fh=fh, X=X_inner)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/sktime/forecasting/base/_base.py?line=444'>445</a> else:
# ...

# %%
import json

# %%
with open('.\Base_Forecasts\Wiki\Wiki_deepar_e200_optuna_in_4.json') as f:
    a = json.loads(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 2
#       1 with open('.\Base_Forecasts\Wiki\Wiki_deepar_e200_optuna_in_4.json') as f:
# ----> 2     a = json.loads(f)
#
# File c:\ProgramData\Anaconda3\lib\json\__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/json/__init__.py?line=336'>337</a> else:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/json/__init__.py?line=337'>338</a>     if not isinstance(s, (bytes, bytearray)):
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/json/__init__.py?line=338'>339</a>         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/json/__init__.py?line=339'>340</a>                         f'not {s.__class__.__name__}')
# ...

# %%
with open('.\Base_Forecasts\Wiki\Wiki_deepar_e200_optuna_in_4.json') as f:
    a = json.load(f)

# %%
len(a)
# Out:
# 15

# %%
def ETS_Prob_Forecast(series,h,sp):
    '''
    Forecast h step using ETS method without seasonal component
    '''
    model = ExponentialSmoothing(endog=series, trend=True,seasonal=sp)
    es_fit_result = model.fit()
    res_df = es_fit_result.get_forecast(h).summary_frame()
    var_pred = (res_df['mean_se']**2).tolist()
    mu_pred = (res_df['mean']).tolist()
    fitted = es_fit_result.fittedvalues.tolist()
    resid = (fitted - series).tolist()
    return [mu_pred,var_pred,resid,fitted]

# %%
res = ETS_Prob_Forecast(endog,15,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 res = ETS_Prob_Forecast(endog,15,1)
#
# Cell In[84], line 5, in ETS_Prob_Forecast(series, h, sp)
#       1 def ETS_Prob_Forecast(series,h,sp):
#       2     '''
#       3     Forecast h step using ETS method without seasonal component
#       4     '''
# ----> 5     model = ExponentialSmoothing(endog=series, trend=True,seasonal=sp)
#       6     es_fit_result = model.fit()
#       7     res_df = es_fit_result.get_forecast(h).summary_frame()
#
# NameError: name 'ExponentialSmoothing' is not defined

# %%
from statsmodels.tsa.statespace.exponential_smoothing import ExponentialSmoothing

# %%
res = ETS_Prob_Forecast(endog,15,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 res = ETS_Prob_Forecast(endog,15,1)
#
# Cell In[84], line 5, in ETS_Prob_Forecast(series, h, sp)
#       1 def ETS_Prob_Forecast(series,h,sp):
#       2     '''
#       3     Forecast h step using ETS method without seasonal component
#       4     '''
# ----> 5     model = ExponentialSmoothing(endog=series, trend=True,seasonal=sp)
#       6     es_fit_result = model.fit()
#       7     res_df = es_fit_result.get_forecast(h).summary_frame()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\exponential_smoothing.py:171, in ExponentialSmoothing.__init__(self, endog, trend, damped_trend, seasonal, initialization_method, initial_level, initial_trend, initial_seasonal, bounds, concentrate_scale, dates, freq)
# ...

# %%
res = ETS_Prob_Forecast(endog,15,0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 res = ETS_Prob_Forecast(endog,15,0)
#
# Cell In[84], line 5, in ETS_Prob_Forecast(series, h, sp)
#       1 def ETS_Prob_Forecast(series,h,sp):
#       2     '''
#       3     Forecast h step using ETS method without seasonal component
#       4     '''
# ----> 5     model = ExponentialSmoothing(endog=series, trend=True,seasonal=sp)
#       6     es_fit_result = model.fit()
#       7     res_df = es_fit_result.get_forecast(h).summary_frame()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\exponential_smoothing.py:232, in ExponentialSmoothing.__init__(self, endog, trend, damped_trend, seasonal, initialization_method, initial_level, initial_trend, initial_seasonal, bounds, concentrate_scale, dates, freq)
# ...

# %%
res = ETS_Prob_Forecast(endog,15,None)

# %%
res
# Out:
# [[638.4071734712062,
#   647.0075670658855,
#   655.6079606605648,
#   664.2083542552441,
#   672.8087478499234,
#   681.4091414446027,
#   690.009535039282,
#   698.6099286339613,
#   707.2103222286406,
#   715.8107158233199,
#   724.4111094179992,
#   733.0115030126785,
#   741.6118966073578,
#   750.2122902020371,
#   758.8126837967164],
#  [58606.76896672225,
#   59059.635933770194,
#   59833.99499730019,
#   61015.563060602064,
#   62690.057026965675,
#   64943.19379968088,
#   67860.69028203747,
#   71528.26337732536,
#   76031.62998883432,
#   81456.50701985424,
#   87888.61137367494,
#   95413.65995358625,
#   104117.36966287806,
#   114085.45740484016,
#   125403.64008276242],
#  [334.4751908741623,
#   -118.61010054780581,
#   -2740.9121197375066,
#   -134.49432371854027,
#   151.92813923193944,
#   626.809801891714,
#   868.8387051137615,
#   846.6417558189291,
#   342.9005837014479,
#   -499.45461793874665,
#   -547.0357873553371,
#   -746.9279306544827,
# ...

# %%
forecast_results_in.append(res)

# %%
num = 106
print('Start.....')
for j in range(105,199):
    forecast_results_in.append(ARIMA_Prob_Forecast(data_windows[3].iloc[:,(j+1)],15))
# Out:
# Start.....
# 106/199
# 107/199
# 108/199
# 109/199
# 110/199
# 111/199
# 112/199
# 113/199
# 114/199
# 115/199
# 116/199
# 117/199
# 118/199
# 119/199
# 120/199
# 121/199
# 122/199
# 123/199
# 124/199
# 125/199
# 126/199
# 127/199
# 128/199
# 129/199
# 130/199
# 131/199
# c:\ProgramData\Anaconda3\lib\site-packages\pmdarima\arima\_auto_solvers.py:524: ModelFitWarning: Error fitting  ARIMA(3,0,0)(0,0,0)[0] intercept (if you do not want to see these warnings, run with error_action="ignore").
#   warnings.warn(warning_str, ModelFitWarning)
# c:\ProgramData\Anaconda3\lib\site-packages\pmdarima\arima\_auto_solvers.py:524: ModelFitWarning: Error fitting  ARIMA(3,0,1)(0,0,0)[0]           (if you do not want to see these warnings, run with error_action="ignore").
#   warnings.warn(warning_str, ModelFitWarning)
# 132/199
# 133/199
# 134/199
# 135/199
# 136/199
# 137/199
# 138/199
# 139/199
# 140/199
# 141/199
# 142/199
# 143/199
# 144/199
# 145/199
# 146/199
# 147/199
# 148/199
# 149/199
# ...

# %%
len(forecast_results_in)
# Out:
# 796

# %%
# Save the results
with open(f'./Base_Forecasts/{dataset}/{dataset}_in.json','w') as file:
    file.write(json.dumps(forecast_results_in))

# %%
# Save the results
with open(f'./Base_Forecasts/{dataset}/{dataset}_in.json','w') as file:
    file.write(json.dumps(forecast_results_in))
